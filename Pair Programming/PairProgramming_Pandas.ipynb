# %% [markdown]
# # Pandas Data Frames
#
# Carrie Beauzile-Milinazzo 3/26/25
#
# Pandas is a python implementation of the R or SQL style data frame or data table
#
# Indexing is a bit different, and there are some other "wrinkles" to id
#
# There are a lot of member functions (aka methods) in Pandas to do a lot of basic
# data processing
#
# Pandas data frames have variables along columns,  which can be of different types
#
# More resources
#
# https://pandas.pydata.org/

# %%
import pandas as pd

# %% [markdown]
# we will load a data frame descriping public wifi access sites in Boston
#
# the file is called wicked_free_wifi_boston.csv
#
# There is a read_csv function in pandas, that will attempt to assign variable types to
# columns
#
# You will need to insert the full file path into the variable infile below,  or make sure that the file is in the current working
# directory
#
# below is the command from the os library to show the current working directory
#
# we can use os.chdir() to change the current working directory

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\cmilinazzo\\Documents\\USB Drive\\R and Python Programming\\Module 02\\Pair Programming'

# %%
os.chdir('C:\\Users\\cmilinazzo\\Documents\\USB Drive\\R and Python Programming\\Module 02')

# %%
infile="Wicked_Free_WiFi_Locations.csv"

wifi=pd.read_csv(infile)

# %%
# head function,  called as a methd belonging to the dataframe (a python object) called wifi

# wifi is said to be an instance of a python dataframe

wifi.head(7)
# Out:
#               X             Y       neighborhood_id  neighborhood_name  \
# 0           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 1           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 2 -7.912255e+06  5.206228e+06  L_601230550253964116    Nubian-Bus-Stop
# 3           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
# 4           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
# 5 -7.913037e+06  5.209642e+06  N_568579452955527921              Parks
# 6 -7.913800e+06  5.210828e+06  N_579275502070532581            Roxbury
#
#     device_serial                 device_connectedto  \
# 0  Q3AK-SUL7-7FC4                             MR76-1
# 1  Q2ZY-RF99-YN45                             MG41-1
# 2  Q3AE-QFTK-E55W                     ROX-Nubian-AP1
# 3  Q3AK-DU9C-2UXZ                     ROX-Nubian_AP6
# 4  Q3AK-FGAN-3AR9                     ROX-Nubian_AP7
# 5  Q2EK-4PWN-GALS  PARKS-FRANKLIN_CLUBHOUSE-MR84-AP1
# 6  Q2CK-SSY2-PBYW            ROX-Madison Park-HS-AP1
#
#                         device_address  device_lat  device_long  \
# 0                                  NaN         NaN          NaN
# 1                                  NaN         NaN          NaN
# 2  247 Washington St, Boston, MA 02121   42.301350   -71.077000
# 3                                  NaN         NaN          NaN
# 4                                  NaN         NaN          NaN
# 5           1 Circuit Dr., Roxbury, MA   42.324030   -71.084020
# 6  75 Malcolm X Blvd, Boston, MA 02120   42.331905   -71.090878
#
#           device_tags    etl_updatedtimestamp  is_current org1 org2  \
# 0                  []  2024/08/20 04:31:34+00           1  NaN  NaN
# 1                  []  2024/08/20 04:31:34+00           1  NaN  NaN
# 2  ['recently-added']  2024/08/20 04:31:38+00           1  NaN  NaN
# 3                  []  2024/08/20 04:31:38+00           1  NaN  NaN
# 4                  []  2024/08/20 04:31:38+00           1  NaN  NaN
# 5  ['recently-added']  2024/08/20 04:31:39+00           1  NaN  NaN
# 6  ['recently-added']  2024/08/20 04:31:43+00           1  NaN  NaN
#
#   inside_outside landmark  ObjectId
# 0            NaN      NaN         1
# 1            NaN      NaN         2
# 2            NaN      NaN         3
# 3            NaN      NaN         4
# 4            NaN      NaN         5
# 5            NaN      NaN         6
# 6            NaN      NaN         7

# %%
#unlike the R data frames, head doesn't show us the data types
# we need to do that manually, looking at the attribute dtypes

wifi.dtypes
# Out:
# X                       float64
# Y                       float64
# neighborhood_id          object
# neighborhood_name        object
# device_serial            object
# device_connectedto       object
# device_address           object
# device_lat              float64
# device_long             float64
# device_tags              object
# etl_updatedtimestamp     object
# is_current                int64
# org1                     object
# org2                     object
# inside_outside           object
# landmark                 object
# ObjectId                  int64
# dtype: object

# %% [markdown]
# # What is the data type "object" in Pandas
#
# An object is a string storage form

# %%
# Generating a Summary
# describes only numeric values

wifi.describe()
# Out:
#                   X             Y  device_lat  device_long  is_current  \
# count  2.830000e+02  2.830000e+02  283.000000   283.000000       297.0
# mean  -7.912135e+06  5.210210e+06   42.327796   -71.075917         1.0
# std    3.034883e+03  4.447129e+03    0.029537     0.027263         0.0
# min   -7.922403e+06  5.198613e+06   42.250739   -71.168161         1.0
# 25%   -7.913761e+06  5.207725e+06   42.311295   -71.090520         1.0
# 50%   -7.912078e+06  5.210305e+06   42.328431   -71.075407         1.0
# 75%   -7.910171e+06  5.214371e+06   42.355431   -71.058271         1.0
# max   -7.904348e+06  5.218989e+06   42.386080   -71.005970         1.0
#
#          ObjectId
# count  297.000000
# mean   149.000000
# std     85.880731
# min      1.000000
# 25%     75.000000
# 50%    149.000000
# 75%    223.000000
# max    297.000000

# %% [markdown]
# # Subsetting and slicing in pandas

# %%
#accessing a column,  there are several options 

n_name=wifi.neighborhood_name
w_address=wifi["device_address"]

# %% [markdown]
# # Pandas series
# If we extract a column it is in the form of a pandas data series, which still has a lot of pandas style member
# functions

# %%
type(n_name)
# Out:
# pandas.core.series.Series

# %%
# we can convert this to a list, using a member function

n_name_list=n_name.to_list()
type(n_name_list)
# Out:
# list

# %%
# dimensions of a dataframe are obtained using the attribute shape
print(wifi.shape)
print(n_name.shape)
# Out:
# (297, 17)
# (297,)

# %%
#indexing several columns

wifi[["X","Y"]].head()

# When you use single brackets [] with a pandas DataFrame, you're primarily selecting a single column
# Single brackets will return a pandas Series (a one-dimensional labeled array).

# When you use double brackets [[]], you're selecting multiple columns.
# You're passing a list of column names within the outer brackets.
# Out:
#               X             Y
# 0           NaN           NaN
# 1           NaN           NaN
# 2 -7.912255e+06  5.206228e+06
# 3           NaN           NaN
# 4           NaN           NaN

# %% [markdown]
# # *Question/Action*
#
# use head to show the first 5 rows of the neighborhood id and name

# %%
wifi[["neighborhood_id","neighborhood_name"]].head(5)
# Out:
#         neighborhood_id  neighborhood_name
# 0  L_601230550253963849  Mobile WiFi Kit 1
# 1  L_601230550253963849  Mobile WiFi Kit 1
# 2  L_601230550253964116    Nubian-Bus-Stop
# 3  L_601230550253964116    Nubian-Bus-Stop
# 4  L_601230550253964116    Nubian-Bus-Stop

# %%
#Basic calculations

print(wifi.device_lat.max())
print(wifi.device_lat.min())
print(wifi.device_lat.mean())
# Out:
# 42.38608
# 42.2507393
# 42.32779576223686

# %%
# filtering rows using conditional dependence

#let's find all devices with latitude above 42.3271405

above_wifi=wifi[wifi.device_lat>=42.3271405]
above_wifi.head()
# Out:
#                X             Y       neighborhood_id neighborhood_name  \
# 6  -7.913800e+06  5.210828e+06  N_579275502070532581           Roxbury
# 7  -7.913800e+06  5.210828e+06  N_579275502070532581           Roxbury
# 15 -7.912357e+06  5.210581e+06  N_579275502070532581           Roxbury
# 18 -7.912846e+06  5.210317e+06  N_579275502070532581           Roxbury
# 20 -7.912858e+06  5.210361e+06  N_579275502070532581           Roxbury
#
#      device_serial       device_connectedto  \
# 6   Q2CK-SSY2-PBYW  ROX-Madison Park-HS-AP1
# 7   Q2CK-SU8N-5VU8  ROX-Madison Park-HS-AP3
# 15  Q2CK-HDFV-VYBC          ROX-ORCHARD-AP2
# 18  Q2CK-SF4S-8JL2           ROX-BFDE14-AP3
# 20  Q2CK-MR56-4QY6           ROX-BFDE14-AP2
#
#                                        device_address  device_lat  \
# 6                 75 Malcolm X Blvd, Boston, MA 02120   42.331905
# 7                 75 Malcolm X Blvd, Boston, MA 02120   42.331905
# 15                        906 Albany St., Roxbury, MA   42.330267
# 18                  On pole across from BFD Engine 14   42.328514
# 20  174 Dudley St., Roxbury, MA - Front Roof Facin...   42.328809
#
#     device_long                                        device_tags  \
# 6    -71.090878                                 ['recently-added']
# 7    -71.090878                                 ['recently-added']
# 15   -71.077909  ['BPS', 'Orchard-Garden-School', 'Outside', 'r...
# 18   -71.082303                    ['BFD', 'Engine-14', 'Outside']
# 20   -71.082409                    ['BFD', 'Engine-14', 'Outside']
#
#       etl_updatedtimestamp  is_current org1 org2 inside_outside  \
# 6   2024/08/20 04:31:43+00           1  NaN  NaN            NaN
# 7   2024/08/20 04:31:43+00           1  NaN  NaN            NaN
# 15  2024/08/20 04:31:43+00           1  BPS  NaN        Outside
# 18  2024/08/20 04:31:43+00           1  BFD  NaN        Outside
# 20  2024/08/20 04:31:43+00           1  BFD  NaN        Outside
#
#                  landmark  ObjectId
# 6                     NaN         7
# 7                     NaN         8
# 15  Orchard Garden School        16
# 18              Engine 14        19
# 20              Engine 14        21

# %%
#slicing by values in a set, notice that pandas has a isin() member function for this

wifi[wifi.neighborhood_name.isin(["Parks","Charlestown"])]

# .isin() itself returns a boolean Series.
# when you put that boolean Series inside the wifi[...], you're using it to filter the rows of the wifi DataFrame
# Out:
#                 X             Y       neighborhood_id neighborhood_name  \
# 5   -7.913037e+06  5.209642e+06  N_568579452955527921             Parks
# 28  -7.910979e+06  5.214437e+06  N_568579452955527921             Parks
# 44  -7.916707e+06  5.202882e+06  N_568579452955527921             Parks
# 188 -7.910482e+06  5.218089e+06  N_568579452955538062       Charlestown
# 202 -7.910805e+06  5.214387e+06  N_568579452955527921             Parks
# 203 -7.911261e+06  5.214274e+06  N_568579452955527921             Parks
# 205 -7.910482e+06  5.218089e+06  N_568579452955538062       Charlestown
# 214 -7.911012e+06  5.214442e+06  N_568579452955527921             Parks
# 223 -7.910482e+06  5.218089e+06  N_568579452955538062       Charlestown
# 226 -7.911133e+06  5.214283e+06  N_568579452955527921             Parks
# 227 -7.916761e+06  5.208413e+06  N_568579452955527921             Parks
# 228 -7.910954e+06  5.213995e+06  N_568579452955527921             Parks
# 229 -7.916761e+06  5.208413e+06  N_568579452955527921             Parks
# 230 -7.910787e+06  5.214274e+06  N_568579452955527921             Parks
# 231 -7.910746e+06  5.214357e+06  N_568579452955527921             Parks
# 240 -7.916761e+06  5.208413e+06  N_568579452955527921             Parks
# 241 -7.911216e+06  5.214476e+06  N_568579452955527921             Parks
# 242 -7.910801e+06  5.214373e+06  N_568579452955527921             Parks
#
#       device_serial                 device_connectedto  \
# 5    Q2EK-4PWN-GALS  PARKS-FRANKLIN_CLUBHOUSE-MR84-AP1
# 28   Q3AK-CVAE-CUZU                   PARKS-COMMON-AP6
# 44   Q2AK-U4TT-J95L                   PARKS-MTHOPE-AP1
# 188  Q2CK-V3LS-5V65                       CHL-BCYF-AP2
# 202  Q3AK-DGSZ-GM7H                   PARKS-COMMON-AP7
# 203  Q3AK-EK6U-T4FW                   PARKS-COMMON-AP2
# 205  Q2CK-CWUY-RBGW                 CHL-HIGHSCHOOL-AP1
# 214  Q3AK-DRLB-LEZF                   PARKS-COMMON-AP5
# 223  Q2CK-SNTB-WJWA                 CHL-HIGHSCHOOL-AP2
# 226  Q3AK-CR6K-YPBC                   PARKS-COMMON-AP4
# 227  Q2CK-7ANU-RF72              PARKS-JAMAICAPOND-AP1
# 228  Q3AK-CR92-A992                   PARKS-COMMON-AP1
# 229  Q2CD-6YGF-H7PW              PARKS-JAMAICAPOND-AP3
# 230  Q3AK-DGWD-NEFT                  PARKS-COMMON-AP10
# 231  Q3AK-CVAW-H5UM                   PARKS-COMMON-AP9
# 240  Q2CK-7CSR-NUQK              PARKS-JAMAICAPOND-AP2
# 241  Q3AK-CRWB-RXVL                   PARKS-COMMON-AP3
# 242  Q3AK-CQWK-ZYPY                   PARKS-COMMON-AP8
#
#                                         device_address  device_lat  \
# 5                           1 Circuit Dr., Roxbury, MA   42.324030
# 28                                       Boston Common   42.355872
# 44   Mt Hope Cemetery, Hyde Park, MA - Cummings Hwy...   42.279119
# 188              240 Medford St, Charlestown, MA 02129   42.380109
# 202                                      Boston Common   42.355539
# 203                                      Boston Common   42.354786
# 205                   240 Medford St., Charlestown, MA   42.380109
# 214                                      Boston Common   42.355900
# 223              240 Medford St, Charlestown, MA 02129   42.380109
# 226                                      Boston Common   42.354849
# 227     507 Jamaicaway, Jamaica Plain, MA - boat house   42.315867
# 228                                      Boston Common   42.352939
# 229  507 Jamaicaway, Jamaica Plain, MA - inside boa...   42.315867
# 230                                      Boston Common   42.354786
# 231                                      Boston Common   42.355341
# 240      507 Jamaicaway, Jamaica Plain, MA - bandstand   42.315867
# 241                                      Boston Common   42.356126
# 242                                      Boston Common   42.355444
#
#      device_long                                        device_tags  \
# 5     -71.084020                                 ['recently-added']
# 28    -71.065536                                                 []
# 44    -71.116991                 ['Mount-Hope-Cemetery', 'Outside']
# 188   -71.061070  ['BCYF', 'BCYF-Grant', 'Charlestown-Athletic-B...
# 202   -71.063969                                                 []
# 203   -71.068068                                                 []
# 205   -71.061070      ['BPS', 'Charlestown-High-School', 'Outside']
# 214   -71.065831                                                 []
# 223   -71.061070  ['BCYF-Grant', 'BPS', 'Charlestown-High-School...
# 226   -71.066920                                                 []
# 227   -71.117477                        ['Jamaica-Pond', 'Outside']
# 228   -71.065310                                                 []
# 229   -71.117477                        ['Jamaica-Pond', 'Outside']
# 230   -71.063808                                                 []
# 231   -71.063443                                                 []
# 240   -71.117477                        ['Jamaica-Pond', 'Outside']
# 241   -71.067660                                                 []
# 242   -71.063937                                                 []
#
#        etl_updatedtimestamp  is_current  org1 org2 inside_outside  \
# 5    2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 28   2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 44   2024/08/20 04:31:39+00           1   NaN  NaN        Outside
# 188  2024/08/20 04:31:40+00           1  BCYF  NaN        Outside
# 202  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 203  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 205  2024/08/20 04:31:40+00           1   BPS  NaN        Outside
# 214  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 223  2024/08/20 04:31:40+00           1   BPS  NaN        Outside
# 226  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 227  2024/08/20 04:31:39+00           1   NaN  NaN        Outside
# 228  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 229  2024/08/20 04:31:39+00           1   NaN  NaN        Outside
# 230  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 231  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 240  2024/08/20 04:31:39+00           1   NaN  NaN        Outside
# 241  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
# 242  2024/08/20 04:31:39+00           1   NaN  NaN            NaN
#
#                           landmark  ObjectId
# 5                              NaN         6
# 28                             NaN        29
# 44             Mount Hope Cemetery        45
# 188  Charlestown Athletic Building       189
# 202                            NaN       203
# 203                            NaN       204
# 205        Charlestown High School       206
# 214                            NaN       215
# 223        Charlestown High School       224
# 226                            NaN       227
# 227                   Jamaica Pond       228
# 228                            NaN       229
# 229                   Jamaica Pond       230
# 230                            NaN       231
# 231                            NaN       232
# 240                   Jamaica Pond       241
# 241                            NaN       242
# 242                            NaN       243

# %%
# there is also a str.contains function, which searches for a regex string within the column values
# we will talk about regex in more detail later

# notice the use of .str.contains(),   a string function within pandas

# see https://pandas.pydata.org/docs/user_guide/text.html for a bunch of examples of pandas string functions

wifi[wifi.neighborhood_name.str.contains("town")]
# Out:
#                 X             Y       neighborhood_id  \
# 53  -7.910171e+06  5.215103e+06  N_601230550253961310
# 54  -7.910171e+06  5.215103e+06  N_601230550253961310
# 55  -7.909698e+06  5.215107e+06  N_601230550253961310
# 56  -7.909702e+06  5.215082e+06  N_601230550253961310
# 57  -7.910171e+06  5.215103e+06  N_601230550253961310
# 58  -7.909943e+06  5.215065e+06  N_601230550253961310
# 59  -7.910171e+06  5.215103e+06  N_601230550253961310
# 61  -7.909943e+06  5.215065e+06  N_601230550253961310
# 62  -7.910171e+06  5.215103e+06  N_601230550253961310
# 69  -7.909890e+06  5.215063e+06  N_601230550253961310
# 70  -7.910171e+06  5.215103e+06  N_601230550253961310
# 71  -7.910171e+06  5.215103e+06  N_601230550253961310
# 152 -7.910171e+06  5.215103e+06  N_601230550253966673
# 153 -7.910171e+06  5.215103e+06  N_601230550253966673
# 154 -7.910171e+06  5.215103e+06  N_601230550253966673
# 155 -7.910171e+06  5.215103e+06  N_601230550253966673
# 156 -7.910171e+06  5.215103e+06  N_601230550253966673
# 157 -7.910171e+06  5.215103e+06  N_601230550253966673
# 158 -7.910171e+06  5.215103e+06  N_601230550253966673
# 159 -7.910171e+06  5.215103e+06  N_601230550253966673
# 160 -7.910171e+06  5.215103e+06  N_601230550253966673
# 161 -7.910171e+06  5.215103e+06  N_601230550253966673
# 162 -7.910171e+06  5.215103e+06  N_601230550253966673
# 163 -7.910171e+06  5.215103e+06  N_601230550253966673
# 164 -7.910171e+06  5.215103e+06  N_601230550253966673
# 167 -7.910171e+06  5.215103e+06  N_601230550253966673
# 168 -7.910171e+06  5.215103e+06  N_601230550253966673
# 169 -7.910171e+06  5.215103e+06  N_601230550253966673
# 170 -7.910171e+06  5.215103e+06  N_601230550253966673
# 171 -7.910171e+06  5.215103e+06  N_601230550253966673
# 172 -7.910171e+06  5.215103e+06  N_601230550253966673
# 188 -7.910482e+06  5.218089e+06  N_568579452955538062
# 205 -7.910482e+06  5.218089e+06  N_568579452955538062
# 223 -7.910482e+06  5.218089e+06  N_568579452955538062
# 256 -7.910171e+06  5.215103e+06  N_601230550253961310
# 257 -7.910171e+06  5.215103e+06  N_601230550253961310
# 258 -7.910171e+06  5.215103e+06  N_601230550253961310
# 275 -7.910171e+06  5.215103e+06  N_601230550253966673
# 278 -7.910171e+06  5.215103e+06  N_601230550253966673
# 289 -7.909896e+06  5.215085e+06  N_601230550253961310
#
#                                   neighborhood_name   device_serial  \
# 53      Downtown Boston - City Hall - Quincy Market  Q3AE-4FLA-SJCJ
# 54      Downtown Boston - City Hall - Quincy Market  Q3AE-HJRQ-D68Q
# 55      Downtown Boston - City Hall - Quincy Market  Q3AE-ARNB-HFAK
# 56      Downtown Boston - City Hall - Quincy Market  Q3AE-PMFQ-JUX3
# 57      Downtown Boston - City Hall - Quincy Market  Q3AE-3S8D-CZPE
# 58      Downtown Boston - City Hall - Quincy Market  Q3AK-C98F-JUR2
# 59      Downtown Boston - City Hall - Quincy Market  Q3AE-TBT5-D72C
# 61      Downtown Boston - City Hall - Quincy Market  Q3AK-D5DU-9HST
# 62      Downtown Boston - City Hall - Quincy Market  Q3AE-ZUF3-Y73P
# 69      Downtown Boston - City Hall - Quincy Market  Q3AE-F6RV-VVHP
# 70      Downtown Boston - City Hall - Quincy Market  Q3AE-ZXW8-H9ZW
# 71      Downtown Boston - City Hall - Quincy Market  Q3AE-3A2V-JNVG
# 152  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-JBPL-DSNV
# 153  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-ZDPZ-2LNE
# 154  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-QYJ5-RXEJ
# 155  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-2N4M-BWUD
# 156  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-TF7U-TX4P
# 157  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-95XZ-766Y
# 158  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-M6TA-MFWJ
# 159  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-R6BQ-D5KN
# 160  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-M9YS-PAT8
# 161  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-E75T-LLQX
# 162  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-BFV5-YGNC
# 163  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-8YNT-BM6Q
# 164  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-CANN-4NB2
# 167  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-2F27-DVJ3
# 168  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-EETG-KYUS
# 169  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-A943-FE9F
# 170  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-WU87-WVGK
# 171  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-JXU4-QPQ3
# 172  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-A793-TEM9
# 188                                     Charlestown  Q2CK-V3LS-5V65
# 205                                     Charlestown  Q2CK-CWUY-RBGW
# 223                                     Charlestown  Q2CK-SNTB-WJWA
# 256     Downtown Boston - City Hall - Quincy Market  Q3AE-GDTR-3C3W
# 257     Downtown Boston - City Hall - Quincy Market  Q3AE-MULH-9V9B
# 258     Downtown Boston - City Hall - Quincy Market  Q3AE-JLUF-293V
# 275  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-QMTD-57LD
# 278  Downtown Boston - City Hall Plaza and Pavilion  Q3AE-Q4LQ-6HK3
# 289     Downtown Boston - City Hall - Quincy Market  Q3AE-Q7YG-V974
#
#                                 device_connectedto  \
# 53   DT-Beer garden 2- higher level of beer garden
# 54                          DT-CITYHALL-GUARDSHACK
# 55                             DT-QUINCYMARKET-AP2
# 56                             DT-QUINCYMARKET-AP4
# 57             DT-CITYHALL-4th-Floor-Patio-Daycare
# 58                Faneuil-Hall-Marketplace-window1
# 59     DT-Beer garden 1- lower part of beer garden
# 61                 Faneuil-Hall-Marketplace-window
# 62                 DT-CITYHALL-4th-Floor-Patio-AP1
# 69                             DT-QUINCYMARKET-AP3
# 70             DT-CITYHALL-8th-Floor-Interior Ring
# 71                                 DT-CITYHALL-AP1
# 152                                  AP-MR86-CS-23
# 153                                            NaN
# 154                                  AP-MR86-CS-10
# 155                                            NaN
# 156                               AP-MR86-IWF-ROOM
# 157                                            NaN
# 158                                            NaN
# 159                                  AP-MR86-CS-27
# 160                                            NaN
# 161                                  AP-MR86-CS-37
# 162              City Hall Pavilion - Interior AP2
# 163                                 AP-MR86-CS-36?
# 164                                            NaN
# 167                                  AP-MR86-CS-14
# 168                                  AP-MR86-CS-31
# 169              City Hall Pavilion - Interior AP1
# 170                       3rd Floor Lobby Entrance
# 171                                            NaN
# 172                                            NaN
# 188                                   CHL-BCYF-AP2
# 205                             CHL-HIGHSCHOOL-AP1
# 223                             CHL-HIGHSCHOOL-AP2
# 256                                DT-CITYHALL-AP2
# 257            DT-CITYHALL-9th-Floor-Interior Ring
# 258        DT-City Hall Front right side up stairs
# 275                       2nd Floor North Entrance
# 278                                  AP-MR86-CS-09
# 289                            DT-QUINCYMARKET-AP1
#
#                                         device_address  device_lat  \
# 53                   One City Hall Sq  Boston MA 02201   42.360291
# 54                    One City Hall Sq Boston MA 02201   42.360291
# 55           Faneuil Hall Marketplace\nBoston MA 02201   42.360320
# 56           Faneuil Hall Marketplace\nBoston MA 02201   42.360153
# 57                   One City Hall Sq  Boston MA 02201   42.360291
# 58                 1 Faneuil Hall Sq, Boston, MA 02109   42.360039
# 59                   One City Hall Sq  Boston MA 02201   42.360291
# 61                 1 Faneuil Hall Sq, Boston, MA 02109   42.360039
# 62                   One City Hall Sq  Boston MA 02201   42.360291
# 69           Faneuil Hall Marketplace\nBoston MA 02201   42.360022
# 70                   One City Hall Sq\nBoston MA 02201   42.360291
# 71                   One City Hall Sq\nBoston MA 02201   42.360291
# 152     1 City Hall Plaza, Pavilion\nBoston, MA  02201   42.360291
# 153               1 City Hall Square, Boston, MA 02201   42.360291
# 154               1 City Hall Square, Boston, MA 02201   42.360291
# 155                                                NaN   42.360291
# 156  One City Hall Sq, Pavilion Bld, IWF Room,\nBos...   42.360291
# 157                                                NaN   42.360291
# 158                                                NaN   42.360291
# 159     1 City Hall Plaza, Pavilion\nBoston, MA  02201   42.360291
# 160               1 City Hall Square, Boston, MA 02201   42.360291
# 161     1 City Hall Plaza, Pavilion\nBoston, MA  02201   42.360291
# 162  One City Hall Sq, Pavilion Bldg\nBoston, MA 02201   42.360291
# 163     1 City Hall Plaza, Pavilion\nBoston, MA  02201   42.360291
# 164               1 City Hall Square, Boston, MA 02201   42.360291
# 167     1 City Hall Plaza, Pavilion\nBoston, MA  02201   42.360291
# 168     1 City Hall Plaza, Pavilion\nBoston, MA  02201   42.360291
# 169  One City Hall Sq, Pavilion Bldg\nBoston, MA 02201   42.360291
# 170             1 City Hall Plaza, \nBoston, MA  02201   42.360291
# 171               1 City Hall Square, Boston, MA 02201   42.360291
# 172     1 City Hall Plaza, Pavilion\nBoston, MA  02201   42.360291
# 188              240 Medford St, Charlestown, MA 02129   42.380109
# 205                   240 Medford St., Charlestown, MA   42.380109
# 223              240 Medford St, Charlestown, MA 02129   42.380109
# 256                  One City Hall Sq\nBoston MA 02201   42.360291
# 257                 One City Hall Sq.  Boston MA 02201   42.360291
# 258                  One City Hall Sq  Boston MA 02201   42.360291
# 275             1 City Hall Plaza, \nBoston, MA  02201   42.360291
# 278               1 City Hall Square, Boston, MA 02201   42.360291
# 289          Faneuil Hall Marketplace\nBoston MA 02201   42.360169
#
#      device_long                                        device_tags  \
# 53    -71.058271                                                 []
# 54    -71.058271                                                 []
# 55    -71.054029                                                 []
# 56    -71.054061                                                 []
# 57    -71.058271                                                 []
# 58    -71.056228                                                 []
# 59    -71.058271                                                 []
# 61    -71.056228                                 ['recently-added']
# 62    -71.058271                                                 []
# 69    -71.055751                                                 []
# 70    -71.058271                                                 []
# 71    -71.058271                                                 []
# 152   -71.058271                                      ['City-Hall']
# 153   -71.058271                                      ['City-Hall']
# 154   -71.058271                                      ['City-Hall']
# 155   -71.058271                                      ['City-Hall']
# 156   -71.058271                                      ['City-Hall']
# 157   -71.058271                                      ['City-Hall']
# 158   -71.058271                                      ['City-Hall']
# 159   -71.058271                                      ['City-Hall']
# 160   -71.058271                                      ['City-Hall']
# 161   -71.058271                                      ['City-Hall']
# 162   -71.058271                                      ['City-Hall']
# 163   -71.058271                                      ['City-Hall']
# 164   -71.058271                                      ['City-Hall']
# 167   -71.058271                                      ['City-Hall']
# 168   -71.058271                                      ['City-Hall']
# 169   -71.058271                                      ['City-Hall']
# 170   -71.058271                                      ['City-Hall']
# 171   -71.058271                                      ['City-Hall']
# 172   -71.058271                                      ['City-Hall']
# 188   -71.061070  ['BCYF', 'BCYF-Grant', 'Charlestown-Athletic-B...
# 205   -71.061070      ['BPS', 'Charlestown-High-School', 'Outside']
# 223   -71.061070  ['BCYF-Grant', 'BPS', 'Charlestown-High-School...
# 256   -71.058271                                                 []
# 257   -71.058271                                                 []
# 258   -71.058271                                                 []
# 275   -71.058271                                      ['City-Hall']
# 278   -71.058271                                      ['City-Hall']
# 289   -71.055804                                                 []
#
#        etl_updatedtimestamp  is_current  org1 org2 inside_outside  \
# 53   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 54   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 55   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 56   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 57   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 58   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 59   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 61   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 62   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 69   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 70   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 71   2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 152  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 153  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 154  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 155  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 156  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 157  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 158  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 159  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 160  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 161  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 162  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 163  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 164  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 167  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 168  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 169  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 170  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 171  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 172  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 188  2024/08/20 04:31:40+00           1  BCYF  NaN        Outside
# 205  2024/08/20 04:31:40+00           1   BPS  NaN        Outside
# 223  2024/08/20 04:31:40+00           1   BPS  NaN        Outside
# 256  2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 257  2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 258  2024/08/20 04:31:44+00           1   NaN  NaN            NaN
# 275  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 278  2024/08/20 04:31:51+00           1   NaN  NaN            NaN
# 289  2024/08/20 04:31:44+00           1   NaN  NaN            NaN
#
#                           landmark  ObjectId
# 53                             NaN        54
# 54                             NaN        55
# 55                             NaN        56
# 56                             NaN        57
# 57                             NaN        58
# 58                             NaN        59
# 59                             NaN        60
# 61                             NaN        62
# 62                             NaN        63
# 69                             NaN        70
# 70                             NaN        71
# 71                             NaN        72
# 152                      City Hall       153
# 153                      City Hall       154
# 154                      City Hall       155
# 155                      City Hall       156
# 156                      City Hall       157
# 157                      City Hall       158
# 158                      City Hall       159
# 159                      City Hall       160
# 160                      City Hall       161
# 161                      City Hall       162
# 162                      City Hall       163
# 163                      City Hall       164
# 164                      City Hall       165
# 167                      City Hall       168
# 168                      City Hall       169
# 169                      City Hall       170
# 170                      City Hall       171
# 171                      City Hall       172
# 172                      City Hall       173
# 188  Charlestown Athletic Building       189
# 205        Charlestown High School       206
# 223        Charlestown High School       224
# 256                            NaN       257
# 257                            NaN       258
# 258                            NaN       259
# 275                      City Hall       276
# 278                      City Hall       279
# 289                            NaN       290

# %%
# notna returns true or false depending on whether there are Nan values in the locations
# the list of True/False values produced by notna can be used to slice

wifi[wifi.X.notna()].head()
# Out:
#               X             Y       neighborhood_id neighborhood_name  \
# 2 -7.912255e+06  5.206228e+06  L_601230550253964116   Nubian-Bus-Stop
# 5 -7.913037e+06  5.209642e+06  N_568579452955527921             Parks
# 6 -7.913800e+06  5.210828e+06  N_579275502070532581           Roxbury
# 7 -7.913800e+06  5.210828e+06  N_579275502070532581           Roxbury
# 8 -7.913466e+06  5.208391e+06  N_579275502070532581           Roxbury
#
#     device_serial                 device_connectedto  \
# 2  Q3AE-QFTK-E55W                     ROX-Nubian-AP1
# 5  Q2EK-4PWN-GALS  PARKS-FRANKLIN_CLUBHOUSE-MR84-AP1
# 6  Q2CK-SSY2-PBYW            ROX-Madison Park-HS-AP1
# 7  Q2CK-SU8N-5VU8            ROX-Madison Park-HS-AP3
# 8  Q2CK-H5VS-5UKS                    ROX-TROTTER-AP1
#
#                         device_address  device_lat  device_long  \
# 2  247 Washington St, Boston, MA 02121   42.301350   -71.077000
# 5           1 Circuit Dr., Roxbury, MA   42.324030   -71.084020
# 6  75 Malcolm X Blvd, Boston, MA 02120   42.331905   -71.090878
# 7  75 Malcolm X Blvd, Boston, MA 02120   42.331905   -71.090878
# 8       135 Humboldt Ave., Roxbury, MA   42.315723   -71.087872
#
#                             device_tags    etl_updatedtimestamp  is_current  \
# 2                    ['recently-added']  2024/08/20 04:31:38+00           1
# 5                    ['recently-added']  2024/08/20 04:31:39+00           1
# 6                    ['recently-added']  2024/08/20 04:31:43+00           1
# 7                    ['recently-added']  2024/08/20 04:31:43+00           1
# 8  ['BPS', 'Outside', 'Trotter-School']  2024/08/20 04:31:43+00           1
#
#   org1 org2 inside_outside        landmark  ObjectId
# 2  NaN  NaN            NaN             NaN         3
# 5  NaN  NaN            NaN             NaN         6
# 6  NaN  NaN            NaN             NaN         7
# 7  NaN  NaN            NaN             NaN         8
# 8  BPS  NaN        Outside  Trotter School         9

# %%
# Row and column specification
# use paired conctions on [row,column]
# we now have to use the method .loc[] to do this

wifi.loc[wifi.X.notna(),"X"].head()

# (This returns the "X" column directly after filtering, and then uses .head() on that column.)
# Out:
# 2   -7.912255e+06
# 5   -7.913037e+06
# 6   -7.913800e+06
# 7   -7.913800e+06
# 8   -7.913466e+06
# Name: X, dtype: float64

# %%
# you have to have a boolean return type in the row indexing function or a set of integers
# we can send a list of column names to get several of them

wifi.loc[wifi.neighborhood_name.str.contains("Charlestown"),['device_lat','device_long']].head()
# Out:
#      device_lat  device_long
# 188   42.380109    -71.06107
# 205   42.380109    -71.06107
# 223   42.380109    -71.06107

# %%
# Indexing using integer values is done using the iloc[] function

# so remember- used .loc for boolean and named columns,   .iloc for Integer locations

wifi.iloc[0:8,0:6]

# Select rows with integer positions from 0 up to (but not including) 8, and columns 0 through 5 (inclusive)
# Out:
#               X             Y       neighborhood_id  neighborhood_name  \
# 0           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 1           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 2 -7.912255e+06  5.206228e+06  L_601230550253964116    Nubian-Bus-Stop
# 3           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
# 4           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
# 5 -7.913037e+06  5.209642e+06  N_568579452955527921              Parks
# 6 -7.913800e+06  5.210828e+06  N_579275502070532581            Roxbury
# 7 -7.913800e+06  5.210828e+06  N_579275502070532581            Roxbury
#
#     device_serial                 device_connectedto
# 0  Q3AK-SUL7-7FC4                             MR76-1
# 1  Q2ZY-RF99-YN45                             MG41-1
# 2  Q3AE-QFTK-E55W                     ROX-Nubian-AP1
# 3  Q3AK-DU9C-2UXZ                     ROX-Nubian_AP6
# 4  Q3AK-FGAN-3AR9                     ROX-Nubian_AP7
# 5  Q2EK-4PWN-GALS  PARKS-FRANKLIN_CLUBHOUSE-MR84-AP1
# 6  Q2CK-SSY2-PBYW            ROX-Madison Park-HS-AP1
# 7  Q2CK-SU8N-5VU8            ROX-Madison Park-HS-AP3

# %% [markdown]
# # Plotting with Pandas functions
#
# Pandas has basic plotting built in
#
# I typically use Matplotlib, but Pandas has the basics

# %%
#Pandas built in plots

wifi.plot.scatter(x="device_long",y="device_lat")
# Out:
# <Axes: xlabel='device_long', ylabel='device_lat'>

# %%
#here is a boxplot

wifi[["device_long"]].plot.box()

# "device_long" is a column name (a string).
# wifi[["device_long"]] is a DataFrame.
# wifi["device_long"] would be a Series.
# Out:
# <Axes: >

# %%
#histogram

wifi[["device_long"]].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#creating new columns

#just name the column and assign a value

# this is a nonsensical value, but it shows the idea

wifi["x over y"]= wifi.X/wifi.Y

wifi.head()
# Out:
#               X             Y       neighborhood_id  neighborhood_name  \
# 0           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 1           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 2 -7.912255e+06  5.206228e+06  L_601230550253964116    Nubian-Bus-Stop
# 3           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
# 4           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
#
#     device_serial device_connectedto                       device_address  \
# 0  Q3AK-SUL7-7FC4             MR76-1                                  NaN
# 1  Q2ZY-RF99-YN45             MG41-1                                  NaN
# 2  Q3AE-QFTK-E55W     ROX-Nubian-AP1  247 Washington St, Boston, MA 02121
# 3  Q3AK-DU9C-2UXZ     ROX-Nubian_AP6                                  NaN
# 4  Q3AK-FGAN-3AR9     ROX-Nubian_AP7                                  NaN
#
#    device_lat  device_long         device_tags    etl_updatedtimestamp  \
# 0         NaN          NaN                  []  2024/08/20 04:31:34+00
# 1         NaN          NaN                  []  2024/08/20 04:31:34+00
# 2    42.30135      -71.077  ['recently-added']  2024/08/20 04:31:38+00
# 3         NaN          NaN                  []  2024/08/20 04:31:38+00
# 4         NaN          NaN                  []  2024/08/20 04:31:38+00
#
#    is_current org1 org2 inside_outside landmark  ObjectId  x over y
# 0           1  NaN  NaN            NaN      NaN         1       NaN
# 1           1  NaN  NaN            NaN      NaN         2       NaN
# 2           1  NaN  NaN            NaN      NaN         3 -1.519767
# 3           1  NaN  NaN            NaN      NaN         4       NaN
# 4           1  NaN  NaN            NaN      NaN         5       NaN

# %% [markdown]
# # Aggregation or grouping for tables and statistics
#
# Pandas has a nice groupby function,  reminiscent of the dplyr methods

# %%
# we specify the columns we want to work with in the dataframe, then specify which are the grouping variables

# at the end, we add a Pandas summary function

# Note, if we had more grouping variables the input to groupby could be a list


wifi[["device_long","device_lat","neighborhood_name"]].groupby("neighborhood_name").mean()

# To get useful results from a GroupBy object, you need to apply an aggregation function to it.
# For example, .mean() or .sum()
# Otherwise you get a GroupBy object (that represents the grouping operation)
# Out:
#                                                 device_long  device_lat
# neighborhood_name
# 2 Center Plaza                                   -71.060201   42.359796
# Alston Brighton                                  -71.146410   42.350730
# BCYF Indoor                                      -71.084504   42.320980
# BCYF Tremont                                     -71.098229   42.332227
# BCYF-Curley                                      -71.035150   42.329115
# Bolling                                          -71.083664   42.330141
# Charlestown                                      -71.061070   42.380109
# City Hall Truck                                         NaN         NaN
# Dorchester                                       -71.067166   42.306111
# Downtown Boston - City Hall - Quincy Market      -71.057176   42.360229
# Downtown Boston - City Hall Plaza and Pavilion   -71.058271   42.360291
# East Boston                                      -71.038550   42.370514
# East Boston Senior Center                        -71.005970   42.386080
# Hyde Park                                        -71.122637   42.255603
# Jamaica Plain                                    -71.114836   42.309554
# Maintenance                                      -71.063579   42.347038
# Mattahunt BCYF                                   -71.103910   42.275826
# Mattapan-Bus-stop                                -71.093735   42.268617
# Mobile WiFi Kit 1                                       NaN         NaN
# Mobile WiFi Kit 2                                       NaN         NaN
# Mobile WiFi Kit 3                                       NaN         NaN
# Mobile WiFi Kit 4                                       NaN         NaN
# Mobile WiFi Kit 5                                       NaN         NaN
# NOC-TEST                                         -71.076985   42.331899
# Navy Yard                                        -71.053276   42.373728
# Nubian-Bus-Stop                                  -71.077000   42.301350
# OPAT                                             -71.082958   42.331086
# Parks                                            -71.080528   42.340156
# Roslindale                                       -71.128088   42.286149
# Roxbury                                          -71.082860   42.320404
# South Boston                                     -71.037557   42.332484
# Strand Theatre - External                        -71.065961   42.315948
# Strand Theatre - Internal                        -71.065961   42.315948
# YEE Tremont                                      -71.098240   42.332229

# %% [markdown]
# ## Multiple grouping variables

# %%
# we can use groupby to get counts per grouping variable as well
# I tried using is_current as a grouping variable, but they are all 1, indicating current

wifi[["device_long","device_lat","neighborhood_name","is_current"]].groupby(["neighborhood_name","is_current"]).count()
# Out:
#                                                            device_long  \
# neighborhood_name                              is_current
# 2 Center Plaza                                 1                     6
# Alston Brighton                                1                     6
# BCYF Indoor                                    1                    27
# BCYF Tremont                                   1                     9
# BCYF-Curley                                    1                    12
# Bolling                                        1                     6
# Charlestown                                    1                     3
# City Hall Truck                                1                     0
# Dorchester                                     1                    24
# Downtown Boston - City Hall - Quincy Market    1                    16
# Downtown Boston - City Hall Plaza and Pavilion 1                    21
# East Boston                                    1                     9
# East Boston Senior Center                      1                     5
# Hyde Park                                      1                    12
# Jamaica Plain                                  1                     6
# Maintenance                                    1                     6
# Mattahunt BCYF                                 1                     5
# Mattapan-Bus-stop                              1                     2
# Mobile WiFi Kit 1                              1                     0
# Mobile WiFi Kit 2                              1                     0
# Mobile WiFi Kit 3                              1                     0
# Mobile WiFi Kit 4                              1                     0
# Mobile WiFi Kit 5                              1                     0
# NOC-TEST                                       1                     2
# Navy Yard                                      1                     3
# Nubian-Bus-Stop                                1                     5
# OPAT                                           1                     2
# Parks                                          1                    15
# Roslindale                                     1                     5
# Roxbury                                        1                    52
# South Boston                                   1                     6
# Strand Theatre - External                      1                     3
# Strand Theatre - Internal                      1                    10
# YEE Tremont                                    1                     5
#
#                                                            device_lat
# neighborhood_name                              is_current
# 2 Center Plaza                                 1                    6
# Alston Brighton                                1                    6
# BCYF Indoor                                    1                   27
# BCYF Tremont                                   1                    9
# BCYF-Curley                                    1                   12
# Bolling                                        1                    6
# Charlestown                                    1                    3
# City Hall Truck                                1                    0
# Dorchester                                     1                   24
# Downtown Boston - City Hall - Quincy Market    1                   16
# Downtown Boston - City Hall Plaza and Pavilion 1                   21
# East Boston                                    1                    9
# East Boston Senior Center                      1                    5
# Hyde Park                                      1                   12
# Jamaica Plain                                  1                    6
# Maintenance                                    1                    6
# Mattahunt BCYF                                 1                    5
# Mattapan-Bus-stop                              1                    2
# Mobile WiFi Kit 1                              1                    0
# Mobile WiFi Kit 2                              1                    0
# Mobile WiFi Kit 3                              1                    0
# Mobile WiFi Kit 4                              1                    0
# Mobile WiFi Kit 5                              1                    0
# NOC-TEST                                       1                    2
# Navy Yard                                      1                    3
# Nubian-Bus-Stop                                1                    5
# OPAT                                           1                    2
# Parks                                          1                   15
# Roslindale                                     1                    5
# Roxbury                                        1                   52
# South Boston                                   1                    6
# Strand Theatre - External                      1                    3
# Strand Theatre - Internal                      1                   10
# YEE Tremont                                    1                    5

# %% [markdown]
# # Categorical data
#
# We can set data to be of type Categorical,  which is akin to a factor
#
# It is also possible to use integer group codes or dummy coding to represent categories or factors,  this is done using utility tools in
# libraries such as scikit-learn or keras that focus on modeling

# %%
wifi['neighborhood_name']=pd.Categorical(wifi.neighborhood_name)

wifi.head()

# This code changes the way pandas stores and handles the "neighborhood_name" column.
# Instead of storing the full text of each neighborhood name for every row, pandas will store a list of unique neighborhood names and then use a code to represent each name in the column. 
# This can save memory and sometimes make things faster.
# Out:
#               X             Y       neighborhood_id  neighborhood_name  \
# 0           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 1           NaN           NaN  L_601230550253963849  Mobile WiFi Kit 1
# 2 -7.912255e+06  5.206228e+06  L_601230550253964116    Nubian-Bus-Stop
# 3           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
# 4           NaN           NaN  L_601230550253964116    Nubian-Bus-Stop
#
#     device_serial device_connectedto                       device_address  \
# 0  Q3AK-SUL7-7FC4             MR76-1                                  NaN
# 1  Q2ZY-RF99-YN45             MG41-1                                  NaN
# 2  Q3AE-QFTK-E55W     ROX-Nubian-AP1  247 Washington St, Boston, MA 02121
# 3  Q3AK-DU9C-2UXZ     ROX-Nubian_AP6                                  NaN
# 4  Q3AK-FGAN-3AR9     ROX-Nubian_AP7                                  NaN
#
#    device_lat  device_long         device_tags    etl_updatedtimestamp  \
# 0         NaN          NaN                  []  2024/08/20 04:31:34+00
# 1         NaN          NaN                  []  2024/08/20 04:31:34+00
# 2    42.30135      -71.077  ['recently-added']  2024/08/20 04:31:38+00
# 3         NaN          NaN                  []  2024/08/20 04:31:38+00
# 4         NaN          NaN                  []  2024/08/20 04:31:38+00
#
#    is_current org1 org2 inside_outside landmark  ObjectId  x over y
# 0           1  NaN  NaN            NaN      NaN         1       NaN
# 1           1  NaN  NaN            NaN      NaN         2       NaN
# 2           1  NaN  NaN            NaN      NaN         3 -1.519767
# 3           1  NaN  NaN            NaN      NaN         4       NaN
# 4           1  NaN  NaN            NaN      NaN         5       NaN

# %%
# did this work?

wifi.dtypes

# yes.
# Out:
# X                        float64
# Y                        float64
# neighborhood_id           object
# neighborhood_name       category
# device_serial             object
# device_connectedto        object
# device_address            object
# device_lat               float64
# device_long              float64
# device_tags               object
# etl_updatedtimestamp      object
# is_current                 int64
# org1                      object
# org2                      object
# inside_outside            object
# landmark                  object
# ObjectId                   int64
# x over y                 float64
# dtype: object

# %% [markdown]
# # *Question/Action*
#
# What other variables should be Categorical variables (there aren't many)
#
# Convert this variable to a category

# %%
# It could make sense to set neighborhood_id, device_connectedto and inside_outside to categories

wifi['neighborhood_id']=pd.Categorical(wifi.neighborhood_id)
wifi['device_connectedto']=pd.Categorical(wifi.device_connectedto)
wifi['inside_outside']=pd.Categorical(wifi.inside_outside)

wifi.dtypes
# Out:
# X                        float64
# Y                        float64
# neighborhood_id         category
# neighborhood_name       category
# device_serial             object
# device_connectedto      category
# device_address            object
# device_lat               float64
# device_long              float64
# device_tags               object
# etl_updatedtimestamp      object
# is_current                 int64
# org1                      object
# org2                      object
# inside_outside          category
# landmark                  object
# ObjectId                   int64
# x over y                 float64
# dtype: object

# %% [markdown]
# # Dummy Coding
#
# It looks like Pandas can generate dummy codes for us
#
# Pandas does not have a 'factor' variable, so in models like multiple regression,   logisitic regression or neural networks, we use dummy coding to code categorical variables.  You will see more on this later.
#
# What does this look like?
#
# What does a True in this table seem to mean?
#
# This is also called "one-hot" encoding, since there is only one "True" per row of the table

# %%
pd.get_dummies(wifi.neighborhood_name)

# pd.get_dummies() transforms a column with categories into a set of columns representing those categories.
# Each row will have a "1" in the column for its category and "0" in all the other columns.
# This is also known as "one-hot encoding."

# The primary value of the dummy variable DataFrame lies in its relationship to the original DataFrame.
# The rows in the get_dummies() DataFrame correspond exactly to the rows in the original DataFrame.
# This is how the model can "learn" the relationships between the original features and the newly created dummy variables.
# If you isolate the get_dummies() DataFrame, you lose this crucial contextual information.
# Out:
#      2 Center Plaza  Alston Brighton  BCYF Indoor  BCYF Tremont  BCYF-Curley  \
# 0             False            False        False         False        False
# 1             False            False        False         False        False
# 2             False            False        False         False        False
# 3             False            False        False         False        False
# 4             False            False        False         False        False
# ..              ...              ...          ...           ...          ...
# 292           False            False        False         False        False
# 293           False            False        False         False        False
# 294           False            False        False         False        False
# 295           False            False        False         False        False
# 296           False            False        False         False        False
#
#      Bolling  Charlestown  City Hall Truck  Dorchester  \
# 0      False        False            False       False
# 1      False        False            False       False
# 2      False        False            False       False
# 3      False        False            False       False
# 4      False        False            False       False
# ..       ...          ...              ...         ...
# 292    False        False            False       False
# 293     True        False            False       False
# 294     True        False            False       False
# 295     True        False            False       False
# 296     True        False            False       False
#
#      Downtown Boston - City Hall - Quincy Market  ...  Navy Yard  \
# 0                                          False  ...      False
# 1                                          False  ...      False
# 2                                          False  ...      False
# 3                                          False  ...      False
# 4                                          False  ...      False
# ..                                           ...  ...        ...
# 292                                        False  ...      False
# 293                                        False  ...      False
# 294                                        False  ...      False
# 295                                        False  ...      False
# 296                                        False  ...      False
#
#      Nubian-Bus-Stop   OPAT  Parks  Roslindale  Roxbury  South Boston  \
# 0              False  False  False       False    False         False
# 1              False  False  False       False    False         False
# 2               True  False  False       False    False         False
# 3               True  False  False       False    False         False
# 4               True  False  False       False    False         False
# ..               ...    ...    ...         ...      ...           ...
# 292            False  False  False       False    False         False
# 293            False  False  False       False    False         False
# 294            False  False  False       False    False         False
# 295            False  False  False       False    False         False
# 296            False  False  False       False    False         False
#
#      Strand Theatre - External  Strand Theatre - Internal  YEE Tremont
# 0                        False                      False        False
# 1                        False                      False        False
# 2                        False                      False        False
# 3                        False                      False        False
# 4                        False                      False        False
# ..                         ...                        ...          ...
# 292                      False                      False        False
# 293                      False                      False        False
# 294                      False                      False        False
# 295                      False                      False        False
# 296                      False                      False        False
#
# [297 rows x 34 columns]

# %% [markdown]
# # *Question/Action*
#
# Create a dummy coding for the variable that you turned into a Categorical variable in the Question above

# %%
pd.get_dummies(wifi.inside_outside)
# Out:
#      Inside  Outside
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False
# ..      ...      ...
# 292   False    False
# 293    True    False
# 294    True    False
# 295    True    False
# 296    True    False
#
# [297 rows x 2 columns]

# %% [markdown]
# # date-time values
#
# It looks like we have one date-time variable in the dataset right now
#
# etl_updatedtimestamp
#
# it looks like a fairly standard format

# %%
wifi.etl_updatedtimestamp.head(5)
# Out:
# 0    2024/08/20 04:31:34+00
# 1    2024/08/20 04:31:34+00
# 2    2024/08/20 04:31:38+00
# 3    2024/08/20 04:31:38+00
# 4    2024/08/20 04:31:38+00
# Name: etl_updatedtimestamp, dtype: object

# %%
wifi.etl_updatedtimestamp=pd.to_datetime(wifi.etl_updatedtimestamp)
wifi.etl_updatedtimestamp.head()
# Out:
# 0   2024-08-20 04:31:34+00:00
# 1   2024-08-20 04:31:34+00:00
# 2   2024-08-20 04:31:38+00:00
# 3   2024-08-20 04:31:38+00:00
# 4   2024-08-20 04:31:38+00:00
# Name: etl_updatedtimestamp, dtype: datetime64[ns, UTC]

# %%
# We can now get days, months, years

wifi.etl_updatedtimestamp.dt.day.head()
# Out:
# 0    20
# 1    20
# 2    20
# 3    20
# 4    20
# Name: etl_updatedtimestamp, dtype: int32

# %%
wifi.etl_updatedtimestamp.dt.month.head()
# Out:
# 0    8
# 1    8
# 2    8
# 3    8
# 4    8
# Name: etl_updatedtimestamp, dtype: int32

# %%
wifi.etl_updatedtimestamp.dt.year.head()
# Out:
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# Name: etl_updatedtimestamp, dtype: int32

# %% [markdown]
# # Converting to Long form
# uses the melt function
#
# https://pandas.pydata.org/docs/reference/api/pandas.melt.html
#
# Form more ideas on wide to long, look up
#
# Pandas pivot
# pandas pivot_table
# pandas unstack
# pandas wide_to_long

# %%
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})

df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
# note we specify a list of i variables and a list of value variables,  much like in tidyR
# wide format to long format

# id_vars=['A'] specifies which column(s) should be used as identifier variables. 
# These columns will be kept as-is in the melted DataFrame.

# value_vars=['B','C'] specifies which column(s) should be unpivoted.
# These columns will be transformed into rows.

pd.melt(df, id_vars=['A'], value_vars=['B','C'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
# alternative form, two id variables
# this is a "composite key" form

pd.melt(df, id_vars=['A','C'], value_vars=['B'])
# Out:
#    A  C variable  value
# 0  a  2        B      1
# 1  b  4        B      3
# 2  c  6        B      5

# %%
# create df2 for question/action

df2 = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c',3:'d'},
                   'B': {0: 1, 1: 3, 2: 5,3: 6},
                   'C': {0: 2, 1: 4, 2: 6,3: 8},
                   'D': {0:"Biscuit",1:"Chips",2:"Banana",3:"hard case"}})
df2
# Out:
#    A  B  C          D
# 0  a  1  2    Biscuit
# 1  b  3  4      Chips
# 2  c  5  6     Banana
# 3  d  6  8  hard case

# %% [markdown]
# # *Question/Action*
#
# Melt df2 to wide form,  using D and A as the index variables,   assign the other two columns as values

# %%
pd.melt(df2, id_vars=['D','A'], value_vars=['B','C'])
# Out:
#            D  A variable  value
# 0    Biscuit  a        B      1
# 1      Chips  b        B      3
# 2     Banana  c        B      5
# 3  hard case  d        B      6
# 4    Biscuit  a        C      2
# 5      Chips  b        C      4
# 6     Banana  c        C      6
# 7  hard case  d        C      8

# %% [markdown]
# # Joins
#
# A join connects two dataframes (or SQL data tables) together based on matching values of keys (identifiers) in the two data frames or tables.
# You may have seen this in R, and we will see it again in SQL.
#
# Joins are done on two dataframes (or tables) at a time, the first is called the "left" table and the second is called the "right" table and several different forms of joins exist.
#
# Joins are done on Pandas data frames are done using the merge function
#
# You can specify the type of join desired,  inner, outer, left, right etc
#
# https://pandas.pydata.org/docs/reference/api/pandas.merge.html

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo',"bix"],'value': [1, 2, 3, 5,11]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],'value': [5, 6, 7, 8]})

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5
# 4  bix     11

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
# this is an inner join of the left frame df1 and the right frame df2
# An inner join returns only the rows where the join keys have matching values in both DataFrames.

# notice that "bix" was dropped

df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        5  foo        5
# 5  foo        5  foo        8

# %% [markdown]
# What's Happening:
# * The first 'foo' in df1 (row 0) matches both 'foo's in df2 (rows 0 and 3). This results in two combined rows.
# * 'bar' in df1 (row 1) matches 'bar' in df2 (row 1). This results in one combined row.
# * 'baz' in df1 (row 2) matches 'baz' in df2 (row 2). This results in one combined row.
# * The second 'foo' in df1 (row 3) also matches both 'foo's in df2 (rows 0 and 3). This results in two more combined rows.
# * 'bix' in df1 (row 4) has no match in df2.

# %%
# here is a left join

# what happens to "bix"?

df1.merge(df2, how="left",left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo      5.0
# 1  foo        1  foo      8.0
# 2  bar        2  bar      6.0
# 3  baz        3  baz      7.0
# 4  foo        5  foo      5.0
# 5  foo        5  foo      8.0
# 6  bix       11  NaN      NaN

# %% [markdown]
# A left merge (or left join) aims to keep all the rows from the left DataFrame (df1 in this case). For each row in the left DataFrame:
# * If there's a matching value in the join key of the right DataFrame (df2), the corresponding columns from the right DataFrame are included in the result.
# * If there's no matching value in the join key of the right DataFrame, the columns from the right DataFrame will have NaN (Not a Number) in the resulting row.
